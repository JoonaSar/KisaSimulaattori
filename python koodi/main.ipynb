# %%
from kisaajat import Kisaajat
from vartio import Vartio
from rataosuus import Kulku, Rasti
from kisa import Kisa
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

def main():
    sarjakohtaiset_maarat = {"punainen": 50, "keltainen": 50}

    kisaajat = Kisaajat(sarjakohtaiset_maarat, 0)
    
    kisa = Kisa("Testikisa", kisaajat)
    

    kisa.lisaa_rataosuus(Rasti("Rasti 1", 90, 1, 100))
    kisa.lisaa_rataosuus(Kulku("Kulku 1", 120, 3, 100))
    kisa.lisaa_rataosuus(Rasti("Rasti 2", 10, 1, 10))
    
    kisaajat.plot_ajat()
    kisaajat.simuloi_rataosuus(kisa.rataosuudet[0])
    kisaajat.plot_ajat()
    

if __name__ == "__main__":
    main()
